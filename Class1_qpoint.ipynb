# %%
library(ggplot2)
head(diamonds)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.0.5"
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %%
qplot(carat, price, data = diamonds)
# Out:
# plot without title

# %%
qplot(log(carat), log(price), data = diamonds)
# Out:
# plot without title

# %%
qplot(log(carat), log(price), colour = color, data = diamonds)
# Out:
# plot without title

# %% [markdown]
# qplot(log(carat), log(price), colour = I("red"), data = diamonds)

# %%
qplot(carat, price, data = diamonds, geom = c("point", "smooth"))
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
set.seed(1410) # Make the sample reproducible
dsmall <- diamonds[sample(nrow(diamonds), 100), ]
dsmall$Class <- NA
dsmall$Class[which(dsmall$carat <= 2)] <- "Low"
# dsmall$Class[which(dsmall$carat > 1 & dsmall$carat <= 2)] <- "Mid"
dsmall$Class[which(dsmall$carat > 2)] <- "High"
qplot(carat, price, data = dsmall, geom = c("point", "smooth"))
qplot(carat, price, data = dsmall, geom = c("point", "smooth"), colour=Class)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "span too small.   fewer data values than degrees of freedom."
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "pseudoinverse used at 2.0076"
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "neighborhood radius 0.0724"
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "reciprocal condition number  0"
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "There are other near singularities as well. 5.9653"
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# ...

# %%
qplot(carat, price, data = dsmall, geom = c("point", "smooth"),
span = 0.2)
# Out:
# Warning message:
# "Ignoring unknown parameters: span"
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(color, price / carat, data = diamonds, geom = "jitter",
alpha = I(1 / 5))
# Out:
# plot without title

# %%
qplot(color, price / carat, data = diamonds, geom = "boxplot")
# Out:
# plot without title

# %%
qplot(carat, data = diamonds, geom = "histogram")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(carat, data = diamonds, geom = "density")
# Out:
# plot without title

# %%
qplot(carat, data = diamonds, geom = c("histogram"))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
#
# ERROR while rich displaying an object: Error: stat_smooth requires the following missing aesthetics: y
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ...

# %%
qplot(date, unemploy / pop, data = economics, geom = "line")
# Out:
# plot without title

# %%
year <- function(x) as.POSIXlt(x)$year + 1900
qplot(unemploy / pop, uempmed, data = economics,
geom = "path", colour = year(date)) + scale_area()
# Out:
# Error in scale_area(): 没有"scale_area"这个函数
# Traceback:

# %%
# Out:
# [1] 1 2 3 4
